# %% [markdown]
# <a href="https://colab.research.google.com/github/youssefkhemiri/ML-algorithms/blob/main/ML_Algorithms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.tree import DecisionTreeClassifier #Arbre de decision
from sklearn.neural_network import MLPClassifier #Reseaux de neurones 
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.ensemble import ExtraTreesClassifier

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
DT=DecisionTreeClassifier(random_state=0, criterion='entropy') 
MLP = MLPClassifier(hidden_layer_sizes=(20, 10), alpha=0.001, max_iter=200)
KNN= KNeighborsClassifier(n_neighbors=5) 
RF= RandomForestClassifier(n_estimators=100, random_state=1)
Ada=AdaBoostClassifier(n_estimators=100, random_state=0)
ExtC=ExtraTreesClassifier(n_estimators=100, random_state=0)

# %%
churn=pd.read_csv('./Churn_Modelling.csv',sep=',',header=0)
X=churn.iloc[:,1:10].values
Y=churn.iloc[:,10].values

# %%
churn.head()
# Out:
#    CustomerId  CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0    15634602          619       1   42       2       0.00              1
# 1    15647311          608       1   41       1   83807.86              1
# 2    15619304          502       1   42       8  159660.80              3
# 3    15701354          699       1   39       1       0.00              2
# 4    15737888          850       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
Xtrain, Xtest, Ytrain, Ytest=train_test_split(X,Y, test_size=0.25, random_state=1)

# %%
Xtrain.shape
# Out:
# (7500, 9)

# %% [markdown]
# #Decision tree classifier

# %%
#implementation
DT=DecisionTreeClassifier(random_state=0, criterion='entropy') 
DT.fit(Xtrain, Ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
Ypredict=DT.predict(Xtest)

# %%
DT.score(Xtest, Ytest)
# Out:
# 0.7944

# %%
#accuracy is our prediction
accuracy_score(Ytest, Ypredict)
# Out:
# 0.7944

# %%
#compare prediction value with acutal one
confusion_matrix(Ytest, Ypredict)
# Out:
# array([[1712,  268],
#        [ 246,  274]])

# %% [markdown]
# ![Capture dՎcran 2022-04-24 224607.png](data:image/png;base64,...)

# %% [markdown]
# #Random forest tree

# %%
RF= RandomForestClassifier(n_estimators=100, random_state=1)
RF.fit(Xtrain, Ytrain)
# Out:
# RandomForestClassifier(random_state=1)

# %%
Ypredict=RF.predict(Xtest)

# %%
RF.score(Xtest, Ytest)
# Out:
# 0.8524

# %%
accuracy_score(Ytest, Ypredict)
# Out:
# 0.8524

# %%
confusion_matrix(Ytest, Ypredict)
# Out:
# array([[1912,   68],
#        [ 301,  219]])

# %% [markdown]
# #Extra trees classifier

# %%
ExtC=ExtraTreesClassifier(n_estimators=100, random_state=0)
ExtC.fit(Xtrain, Ytrain)
# Out:
# ExtraTreesClassifier(random_state=0)

# %%
Ypredict=ExtC.predict(Xtest)

# %%
ExtC.score(Xtest, Ytest)
# Out:
# 0.8516

# %%
accuracy_score(Ytest, Ypredict)
# Out:
# 0.8516

# %%
confusion_matrix(Ytest, Ypredict)
# Out:
# array([[1912,   68],
#        [ 303,  217]])

# %% [markdown]
# #KNeighborsClassifier

# %%
KNC = KNeighborsClassifier(n_neighbors=5) 
KNC.fit(Xtrain, Ytrain)
# Out:
# KNeighborsClassifier()

# %%
Ypredict = KNC.predict(Xtest)

# %%
KNC.score(Xtest, Ytest)
# Out:
# 0.7596

# %%
accuracy_score(Ytest, Ypredict)
# Out:
# 0.7596

# %%
confusion_matrix(Ytest, Ypredict)
# Out:
# array([[1854,  126],
#        [ 475,   45]])

# %% [markdown]
# #Adaboost Classifier

# %%
Ada=AdaBoostClassifier(n_estimators=100, random_state=0)
Ada.fit(Xtest, Ytest)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
Ypredict=Ada.predict(Xtest)

# %%
Ada.score(Xtest, Ytest)
# Out:
# 0.8612

# %%
accuracy_score(Ytest, Ypredict)
# Out:
# 0.8612

# %%
confusion_matrix(Ytest, Ypredict)
# Out:
# array([[1883,   97],
#        [ 250,  270]])

# %% [markdown]
# #MLP Classifier

# %%
MLP = MLPClassifier(hidden_layer_sizes=(20, 10), alpha=0.001, max_iter=200)
MLP.fit(Xtest, Ytest)
# Out:
# MLPClassifier(alpha=0.001, hidden_layer_sizes=(20, 10))

# %%
Ypredict=MLP.predict(Xtest)

# %%
MLP.score(Xtest, Ytest)
# Out:
# 0.6644

# %%
accuracy_score(Ytest, Ypredict)
# Out:
# 0.6644

# %%
confusion_matrix(Ytest, Ypredict)
# Out:
# array([[1566,  414],
#        [ 425,   95]])
